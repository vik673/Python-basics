# %% [markdown]
# Conditionals
#
# By default, statements in Python script are executed sequentially from top to bottom. If the processing logic require so, the sequential flow of execution can be altered in two way:
#
# Conditional execution: a block of one or more statements will be executed if a certain expression is true
# Repetitive execution: a block of one or more statements will be repetitively executed as long as a certain expression is true. In this section, we will cover if, else, elif statements. The comparison and logical operators we learned in previous sections will be useful here.

# %% [markdown]
# If Condition
#
# In python and other programming languages the key word if is used to check if a condition is true and to execute the block code. Remember the indentation after the colon.

# %% [raw]
# # syntax
# if condition:
#     this part of code runs for truthy conditions

# %%
a = 3
if a > 0:
    print('A is a positive number')
# A is a positive number
# Out:
# A is a positive number

# %% [raw]
# As you can see in the example above, 3 is greater than 0. The condition was true and the block code was executed. However, if the condition is false, we do not see the result. In order to see the result of the falsy condition, we should have another block, which is going to be else.

# %% [raw]
# If Else
#
# If condition is true the first block will be executed, if not the else condition will run.
#
# # syntax
# if condition:
#     this part of code runs for truthy conditions
# else:
#      this part of code runs for false conditions

# %%
a = 3
if a < 0:
    print('A is a negative number')
else:
    print('A is a positive number')
# Out:
# A is a positive number

# %% [markdown]
# The condition above proves false, therefore the else block was executed. How about if our condition is more than two? We could use _ elif_.

# %% [markdown]
# # If Elif Else
#
# In our daily life, we make decisions on daily basis. We make decisions not by checking one or two conditions but multiple conditions. As similar to life, programming is also full of conditions. We use elif when we have multiple conditions.

# %% [raw]
# # syntax
# if condition:
#     code
# elif condition:
#     code
# else:
#     code

# %%
a = 0
if a > 0:
    print('A is a positive number')
elif a < 0:
    print('A is a negative number')
else:
    print('A is zero')
# Out:
# A is zero

# %% [raw]
# # syntax
# code if condition else code

# %%
a = 3
print('A is positive') if a > 0 else print('A is negative') # first condition met, 'A is positive' will be printed
# Out:
# A is positive

# %% [markdown]
# Nested Conditions
#
# Conditions can be nested

# %% [raw]
# # syntax
# if condition:
#     code
#     if condition:
#     code

# %%
a = 0
if a > 0:
    if a % 2 == 0:
        print('A is a positive and even integer')
    else:
        print('A is a positive number')
elif a == 0:
    print('A is zero')
else:
    print('A is a negative number')
# Out:
# A is zero

# %% [markdown]
# We can avoid writing nested condition by using logical operator and.

# %% [raw]
# If Condition and Logical Operators

# %% [raw]
# # syntax
# if condition and condition:
#     code

# %%
a = 0
if a > 0 and a % 2 == 0:
        print('A is an even and positive integer')
elif a > 0 and a % 2 !=  0:
     print('A is a positive integer')
elif a == 0:
    print('A is zero')
else:
    print('A is negative')
# Out:
# A is zero

# %% [markdown]
# If and Or Logical Operators

# %% [raw]
# # syntax
# if condition or condition:
#     code

# %%
user = 'James'
access_level = 3
if user == 'admin' or access_level >= 4:
        print('Access granted!')
else:
    print('Access denied!')
# Out:
# Access denied!

# %% [markdown]
# ### Excercise

# %%
age = int(input("Enter your age"))
if(age >= 18):
    print("You are old enough to learn to drive")
else:
    print("You need ", 18-age, "more year to drive")
# Out:
# Enter your age 2
# You need  16 more year to drive

# %%
yourAge = int(input("Enter your age"))
myAge = int(input("Enter my age"))

if(yourAge > myAge):
    print("you are", yourAge-myAge, "Elder than me.")
elif(yourAge == myAge):
    print("We both have same age")
else:
    print("You are", myAge - yourAge, "Younger than me" )
# Out:
# Enter your age 67
# Enter my age 89
# You are 22 Younger than me

# %%
num1 = int(input("Enter number one: "))
num2 = int(input("Enter number two: "))
if(num1 > num2):
    print(num1,"is greater than" ,num2)
elif(num1==num2):
    print(num1 ,"is equal to ", num2)
else:
    print(num1 ,"is less than" , num2)
# Out:
# Enter number one:  1
# Enter number two:  3
# 1 is less than 3

# %%
score = int(input("Enter your score"))

if(score>= 80 and score <= 100):
    print("Your grade is A")
elif(score>= 70 and score <= 79):
    print("Your grade is B")
elif(score>= 60 and score < 69):
    print("Your grade is C")
elif(score>= 50 and score < 59):
    print("Your grade is D")
elif(score>= 0 and score < 49):
    print("Your grade is F")
# Out:
# Enter your score 78
# Your grade is B

# %%
season = ["Autumn", "Winter", "Spring", "Summer"]
list1 = ['September',  'October', 'November']
list2 = ['December', 'January',  'February']
list3 = ['March', 'April', 'May']
list4 = ['June', 'July', 'August']

month = input("Enter the month")

if(month in list1):
    print(season[0])
elif(month in list2):
    print(season[1])
elif(month in list3):
    print(season[2])
else:
     print(season[3])
# Out:
# Enter the month June
# Summer

# %%
fruits = ['banana', 'orange', 'mango', 'lemon']

fruit = input("Enter fruit do you want")

if(fruit not in fruits):
    fruits.append(fruit)
    print("we have", fruits ,"available")
else:
    print("we have", fruits ,"available")
# Out:
# Enter fruit do you want kela
# we have ['banana', 'orange', 'mango', 'lemon', 'kela'] available

# %%
person={
    'first_name': 'Asabeneh',
    'last_name': 'Yetayeh',
    'age': 250,
    'country': 'Finland',
    'is_marred': True,
    'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address': {
        'street': 'Space street',
        'zipcode': '02210'
    }
    }

# %%
if('skills' in person):
    print(person['skills'][int(len(person['skills'])/2)])
# Out:
# Node

# %%
if('Python' in person['skills']):
    print(person['skills'][person['skills'].index('Python')])
# Out:
# Python

# %% [raw]
# If a person skills has only JavaScript and React,
#  print('He is a front end developer'),
# if the person skills has Node, Python, MongoDB,
# print('He is a backend developer'),
# if the person skills has React, Node and MongoDB,
#  Print('He is a fullstack developer'),
# else print('unknown title')

# %%
if('javaScript' in person['skills']):
    if('React' in person['skills']):
        print('He is a front end developer')
elif('Node' in person['skills'] and 'MongoDB' in person['skills']):
    if('Python' in person['skills']):
        print('He is a backend developer')
    elif('React' in person['skills']):
        print('He is a fullstack developer')
else:
    print("unknown title")
# Out:
# He is a backend developer

# %%
if(person['is_marred'] and person['country'] == 'Finland'):
    print(person['first_name'] , person['last_name'], "Asabeneh Yetayeh lives in", person['country'],". He is married.")
# Out:
# Asabeneh Yetayeh Asabeneh Yetayeh lives in Finland . He is married.

# %% [markdown]
# # Arithmetic Operator

# %%
# Arithmetic Operations in Python
# Integers

print('Addition: ', 1 + 2)        # 3
print('Subtraction: ', 2 - 1)     # 1
print('Multiplication: ', 2 * 3)  # 6
print ('Division: ', 4 / 2)       # 2.0  Division in Python gives floating number
print('Division: ', 6 / 2)        # 3.0         
print('Division: ', 7 / 2)        # 3.5
print('Division without the remainder: ', 7 // 2)   # 3,  gives without the floating number or without the remaining
print ('Division without the remainder: ',7 // 3)   # 2
print('Modulus: ', 3 % 2)         # 1, Gives the remainder
print('Exponentiation: ', 2 ** 3) # 9 it means 2 * 2 * 2
# Out:
# Addition:  3
# Subtraction:  1
# Multiplication:  6
# Division:  2.0
# Division:  3.0
# Division:  3.5
# Division without the remainder:  3
# Division without the remainder:  2
# Modulus:  1
# Exponentiation:  8

# %%
# Floating numbers
print('Floating Point Number, PI', 3.14)
print('Floating Point Number, gravity', 9.81)
# Out:
# Floating Point Number, PI 3.14
# Floating Point Number, gravity 9.81

# %%
# Complex numbers
print('Complex number: ', 1 + 1j)
print('Multiplying complex numbers: ',(1 + 1j) * (1 - 1j))
# Out:
# Complex number:  (1+1j)
# Multiplying complex numbers:  (2+0j)

# %%
# Declaring the variable at the top first

a = 3 # a is a variable name and 3 is an integer data type
b = 2 # b is a variable name and 3 is an integer data type

# Arithmetic operations and assigning the result to a variable
total = a + b
diff = a - b
product = a * b
division = a / b
remainder = a % b
floor_division = a // b
exponential = a ** b

# I should have used sum instead of total but sum is a built-in function - try to avoid overriding built-in functions
print(total) # if you do not label your print with some string, you never know where the result is coming from
print('a + b = ', total)
print('a - b = ', diff)
print('a * b = ', product)
print('a / b = ', division)
print('a % b = ', remainder)
print('a // b = ', floor_division)
print('a ** b = ', exponential)
# Out:
# 5
# a + b =  5
# a - b =  1
# a * b =  6
# a / b =  1.5
# a % b =  1
# a // b =  1
# a ** b =  9

# %%
print('== Addition, Subtraction, Multiplication, Division, Modulus ==')

# Declaring values and organizing them together
num_one = 3
num_two = 4

# Arithmetic operations
total = num_one + num_two
diff = num_two - num_one
product = num_one * num_two
div = num_two / num_one
remainder = num_two % num_one

# Printing values with label
print('total: ', total)
print('difference: ', diff)
print('product: ', product)
print('division: ', div)
print('remainder: ', remainder)
# Out:
# == Addition, Subtraction, Multiplication, Division, Modulus ==
# total:  7
# difference:  1
# product:  12
# division:  1.3333333333333333
# remainder:  1

# %%
# Calculating area of a circle
radius = 10                                 # radius of a circle
area_of_circle = 3.14 * radius ** 2         # two * sign means exponent or power
print('Area of a circle:', area_of_circle)

# Calculating area of a rectangle
length = 10
width = 20
area_of_rectangle = length * width
print('Area of rectangle:', area_of_rectangle)

# Calculating a weight of an object
mass = 75
gravity = 9.81
weight = mass * gravity
print(weight, 'N')                         # Adding unit to the weight

# Calculate the density of a liquid
mass = 75 # in Kg
volume = 0.075 # in cubic meter
density = mass / volume # 1000 Kg/m^3
# Out:
# Area of a circle: 314.0
# Area of rectangle: 200
# 735.75 N

# %% [markdown]
# # Comparison Operators

# %%
print(3 > 2)     # True, because 3 is greater than 2
print(3 >= 2)    # True, because 3 is greater than 2
print(3 < 2)     # False,  because 3 is greater than 2
print(2 < 3)     # True, because 2 is less than 3
print(2 <= 3)    # True, because 2 is less than 3
print(3 == 2)    # False, because 3 is not equal to 2
print(3 != 2)    # True, because 3 is not equal to 2
print(len('mango') == len('avocado'))  # False
print(len('mango') != len('avocado'))  # True
print(len('mango') < len('avocado'))   # True
print(len('milk') != len('meat'))      # False
print(len('milk') == len('meat'))      # True
print(len('tomato') == len('potato'))  # True
print(len('python') > len('dragon'))   # False


# Comparing something gives either a True or False

print('True == True: ', True == True)
print('True == False: ', True == False)
print('False == False:', False == False)
# Out:
# True
# True
# False
# True
# True
# False
# True
# False
# True
# True
# False
# True
# True
# False
# True == True:  True
# True == False:  False
# False == False: True

# %%
print('1 is 1', 1 is 1)                   # True - because the data values are the same
print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
print('A in Asabeneh', 'A' in 'Asabeneh') # True - A found in the string
print('B in Asabeneh', 'B' in 'Asabeneh') # False - there is no uppercase B
print('coding' in 'coding for all') # True - because coding for all has the word coding
print('a in an:', 'a' in 'an')      # True
print('4 is 2 ** 2:', 4 is (2 ** 2))   # True
# Out:
# 1 is 1 True
# 1 is not 2 True
# A in Asabeneh True
# B in Asabeneh False
# True
# a in an: True
# 4 is 2 ** 2: True
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\jaiswal\AppData\Local\Temp\ipykernel_18928\2707040904.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print('1 is 1', 1 is 1)                   # True - because the data values are the same
# C:\Users\jaiswal\AppData\Local\Temp\ipykernel_18928\2707040904.py:2: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
# ...

# %% [markdown]
# # Logical Operators

# %%
print(3 > 2 and 4 > 3) # True - because both statements are true
print(3 > 2 and 4 < 3) # False - because the second statement is false
print(3 < 2 and 4 < 3) # False - because both statements are false
print('True and True: ', True and True)
print(3 > 2 or 4 > 3)  # True - because both statements are true
print(3 > 2 or 4 < 3)  # True - because one of the statements is true
print(3 < 2 or 4 < 3)  # False - because both statements are false
print('True or False:', True or False)
print(not 3 > 2)     # False - because 3 > 2 is true, then not True gives False
print(not True)      # False - Negation, the not operator turns true to false
print(not False)     # True
print(not not True)  # True
print(not not False) # False
# Out:
# True
# False
# False
# True and True:  True
# True
# True
# False
# True or False: True
# False
# False
# True
# True
# False

# %% [markdown]
# ### Excercise

# %%
age = 10
height = 15.8
complex_number = 1 +2j

# %%
base = int(input("Enter the base value"))
height = int(input("Enter the height of traingle"))
area_of_traingle = 0.5 * base * height
print("area of the traingle is: ",area_of_traingle)
# Out:
# Enter the base value 20
# Enter the height of traingle 30
# area of the traingle is:  300.0

# %%
side_a = int(input("Enter the side A of the rectangle"))
side_b = int(input("Enter the side B of the rectangle"))
side_c = int(input("Enter the side C of the rectangle"))
perimeter = side_a + side_b + side_c
print("Perimeter of the rectangle is :", perimeter)
# Out:
# Enter the side A of the rectangle 20
# Enter the side B of the rectangle 30
# Enter the side C of the rectangle 40
# Perimeter of the rectangle is : 90

# %%
length = int(input("Enter the length and width of the rectangle"))
width = int(input("Enter the width of the Rectangle"))
area = 2 * length * width
perimeter = 2 * (length + width)
print("Area of the rectangle is", area)
print("Primeter of the Rectangle is", perimeter)
# Out:
# Enter the length and width of the rectangle 10
# Enter the width of the Rectangle 20
# Area of the rectangle is 400
# Primeter of the Rectangle is 60

# %%
pi = 3.14
radious = 30
area_of_circle = pi * radious * radious
print("Radious of the circle is:", area_of_circle)
# Out:
# Radious of the circle is: 2826.0

# %%
x = int(input("Enter the x value"))
y = 2*x - x
print("slope of y is :", y)
# Out:
# Enter the x value 5
# slope of y is : 5

# %%
import math
x1 = int(input("Enter the x1 point"))
y1 = int(input("Enter the y1 point"))
x2 = int(input("Enter the x2 point"))
y2 = int(input("Enter the y2 point"))
slope = (y2-y1) / (x2 - x1)
euclidean_distance = math.sqrt((y2-y1) ** 2 + (x2-x1) ** 2 )
print("Slope of the curve is ",slope)
print("euclidean distance is ", euclidian_distance)
# Out:
# Enter the x1 point 1
# Enter the y1 point 2
# Enter the x2 point 2
# Enter the y2 point 4
# Slope of the curve is  2.0
# euclidean distance is  2.8284271247461903

# %%
x = int(input("Enter the x value"))
y = (x ** 2) + 6 * x + 9
print("y value is :", y)

# on -3 x value, Y value is going to be zero.
# Out:
# Enter the x value -3
# y value is : 0

# %%
python = "Python"
dragen = "Dragen"
if(len(python) != len(dragen)):
    print("length of the python is", len(python))
else:
    print("length of the dragen is", len(dragen))
# Out:
# length of the dragen is 6

# %%
python = "Python"
dragen = "Dragon"
if(python.endswith("on") and dragen.endswith("on")):
    print(python + " " + dragen)
# Out:
# Python Dragon

# %%
Sentence = "I hope this course is not full of jargon"
if("jargon" in Sentence):
    print(Sentence)
# Out:
# I hope this course is not full of jargon

# %%
if("on" is not python and "on" is not dragen):
    print(python, dragen)
# Out:
# Python Dragon
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\jaiswal\AppData\Local\Temp\ipykernel_18928\3575894131.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if("on" is not python and "on" is not dragen):
# C:\Users\jaiswal\AppData\Local\Temp\ipykernel_18928\3575894131.py:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if("on" is not python and "on" is not dragen):

# %%
print(int(len(python)))
print(float(len(python)))
print(str(len(python)))
# Out:
# 6
# 6.0
# 6

# %%
number = int(input("Enter the integer"))
is_even = 0 if number % 2 else 1
if(is_even):
    print("Number is Even")
else:
    print("Number is odd")
# Out:
# Enter the integer 2
# Number is Even

# %%
div = 7 // 3
flor_to_int = int(2.7)
if(div is flor_to_int):
    print("Both are equal")
# Out:
# Both are equal

# %%
if(type("10") is type(10)):
    print("Both the type are equal")
else:
    print("Both the type are not equal")
# Out:
# Both the type are not equal

# %%
if(int(9.8) is 10):
    print("Yes")
else:
    print("No")
# Out:
# No
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\jaiswal\AppData\Local\Temp\ipykernel_18928\2307797960.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if(int(9.8) is 10):

# %%
hour = 10
rate_per_hour = 10
income = hour *  rate_per_hour
print(income)
# Out:
# 100

# %%
lived = int(input("Enter the number that you have lived"))
total_second = lived * 365 * 24 * 60 * 60
print(" You have lived for " , total_second , " seconds")
# Out:
# Enter the number that you have lived 100
#  You have lived for  3153600000  seconds

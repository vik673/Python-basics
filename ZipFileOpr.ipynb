# %%
from zipfile import ZipFile

# %%
# importing required modules 
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "jcapi.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 file_name = "jcapi.zip"
#       7 # opening the zip file in READ mode
# ----> 8 with ZipFile(file_name, 'r') as zip:
#       9     # printing all the contents of the zip file
#      10     zip.printdir()
#      12     # extracting all the files
#
# File C:\ST_TOOLS\Python\Lib\zipfile.py:1204, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel)
#    1202 while True:
#    1203     try:
# -> 1204         self.fp = io.open(file, filemode)
#    1205     except OSError:
#    1206         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jcapi.zip'

# %%
# printdir() method prints a table of contents for the archive.
# extractall() method will extract all the contents of the zip file to the current working directory. 

# zip.extract('python_files/python_wiki.txt')
# This will extract only the specified file.

# data = zip.read(name_of_file_to_read)

# %%
# infoList() 

zip.infolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # infoList()
# ----> 3 zip.infolist()
#
# AttributeError: type object 'zip' has no attribute 'infolist'

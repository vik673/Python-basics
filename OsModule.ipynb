# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jaiswal\\PycharmProjects'

# %%
pwd
# Out:
# 'C:\\Users\\jaiswal\\PycharmProjects'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0AA2-45F2
#
#  Directory of C:\Users\jaiswal\PycharmProjects
#
# 18-12-2024  14:47    <DIR>          .
# 17-10-2025  16:16    <DIR>          ..
# 03-12-2024  13:38    <DIR>          .ipynb_checkpoints
# 18-11-2025  20:38    <DIR>          30_Days_Of_Python
# 03-12-2024  14:04             1,164 BuildtimePreprocessorVariables.toml
# 03-12-2024  14:04           108,858 CheckJavadocDoclet.log
# 27-09-2024  18:04             3,919 CheckNUpdateXMLFile.ipynb
# 27-09-2024  16:15    <DIR>          demo
# 12-12-2024  10:26    <DIR>          InterViewQuestion
# 03-12-2024  14:04            28,269 native_method_registry.json
# 03-12-2024  13:56            10,411 OsModule.ipynb
# 26-04-2024  18:42    <DIR>          python_basics
# 04-12-2024  12:47    <DIR>          pythonGFG
# 26-08-2024  15:34    <DIR>          pythonProject
# 27-09-2024  15:14    <DIR>          STReleasePkgConfiguratorTool
# ...

# %%
os.chdir("demo")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jaiswal\\PycharmProjects\\demo'

# %%
cd ..
# Out:
# C:\Users\jaiswal\PycharmProjects
# C:\ST_TOOLS\Python\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jaiswal'

# %%
os.mkdir("gfg")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.mkdir("gfg")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'gfg'

# %%
os.makedirs("gfg/gfg/gfg/gfg")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.makedirs("gfg/gfg/gfg/gfg")
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'gfg/gfg/gfg/gfg'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jaiswal'

# %%
os.chdir("PycharmProjects")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jaiswal\\PycharmProjects'

# %%
os.mkdir("gfg")

# %%
os.makedirs("gfg/gfg/gfg/gfg")

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 0AA2-45F2
#
#  Directory of C:\Users\jaiswal\PycharmProjects
#
# 19-11-2025  07:45    <DIR>          .
# 17-10-2025  16:16    <DIR>          ..
# 03-12-2024  13:38    <DIR>          .ipynb_checkpoints
# 18-11-2025  20:38    <DIR>          30_Days_Of_Python
# 03-12-2024  14:04             1,164 BuildtimePreprocessorVariables.toml
# 03-12-2024  14:04           108,858 CheckJavadocDoclet.log
# 27-09-2024  18:04             3,919 CheckNUpdateXMLFile.ipynb
# 27-09-2024  16:15    <DIR>          demo
# 19-11-2025  07:46    <DIR>          gfg
# 12-12-2024  10:26    <DIR>          InterViewQuestion
# 03-12-2024  14:04            28,269 native_method_registry.json
# 03-12-2024  13:56            10,411 OsModule.ipynb
# 26-04-2024  18:42    <DIR>          python_basics
# 04-12-2024  12:47    <DIR>          pythonGFG
# 26-08-2024  15:34    <DIR>          pythonProject
# 27-09-2024  15:14    <DIR>          STReleasePkgConfiguratorTool
# ...

# %%
# this will join the path of dir

os.path.join("gfg","gfg")
# Out:
# 'gfg\\gfg'

# %%
import os 
def current_path(): 
    print("Current working directory before") 
    print(os.getcwd()) 
    print() 
current_path() 
os.chdir('../') 
current_path()
# Out:
# Current working directory before
# C:\Users\jaiswal\PycharmProjects
#
# Current working directory before
# C:\Users\jaiswal

# %%
os.chdir('PycharmProjects')

# %%
import os 
path = "/"
dir_list = os.listdir(path) 
print("Files and directories in '", path, "' :") 
print(dir_list)
# Out:
# Files and directories in ' / ' :
# ['$GetCurrent', '$Recycle.Bin', '$WinREAgent', 'appverifUI.dll', 'buildArtifactsFlavored', 'Config.Msi', 'Documents and Settings', 'DumpStack.log', 'DumpStack.log.tmp', 'hiberfil.sys', 'hp', 'Intel', 'jenkins', 'keil_v5', 'LogBackup', 'msdia80.dll', 'nuget', 'pagefile.sys', 'PerfLogs', 'Program Files', 'Program Files (x86)', 'ProgramData', 'programs', 'python37', 'Recovery', 'refs', 'shreshta', 'SMSTSLog', 'ST_TOOLS', 'swapfile.sys', 'SWSetup', 'System Volume Information', 'system.sav', 'temp', 'Users', 'vfcompat.dll', 'Windows', 'xvi32']
